# %%
import nltk.sentiment.vader as vd

analyzer = vd.SentimentIntensityAnalyzer()
analyzer.polarity_scores("It's a good movie, but need something to make it perfect").values()
# Out:
# dict_values([0.0, 0.533, 0.467, 0.7906])

# %%
x = [[3,4,3,2],[4,3,2]]
y = set()
for i in x:
    y.update(i)
z = {}
z.update({'4':{'5':5}})
z.update({'4':{'6':5}})
z
# Out:
# {'4': {'6': 5}}

# %%
data_x = []
data_y = []
for filename in os.listdir('./train_file/'):
    data_y.append(int(filename.split("_")[1].split(".")[0]))
    f = open('./train_file/' + filename, "r", encoding="utf-8")
    text = f.read()
    data_x.append(analyzer.polarity_scores(text).values())
print(data_x)
# Out:
# [dict_values([0.108, 0.746, 0.146, 0.7003]), dict_values([0.044, 0.916, 0.039, -0.1759]), dict_values([0.159, 0.705, 0.135, -0.974]), dict_values([0.111, 0.739, 0.151, 0.9688]), dict_values([0.078, 0.736, 0.186, 0.9657]), dict_values([0.063, 0.795, 0.142, 0.9111]), dict_values([0.122, 0.717, 0.161, 0.8791]), dict_values([0.021, 0.812, 0.167, 0.9453]), dict_values([0.151, 0.743, 0.106, -0.9663]), dict_values([0.012, 0.809, 0.179, 0.9731]), dict_values([0.12, 0.798, 0.082, -0.4497]), dict_values([0.046, 0.781, 0.174, 0.9609]), dict_values([0.089, 0.842, 0.07, -0.2964]), dict_values([0.0, 0.788, 0.212, 0.9744]), dict_values([0.066, 0.777, 0.157, 0.9674]), dict_values([0.021, 0.825, 0.154, 0.9938]), dict_values([0.157, 0.625, 0.218, 0.6369]), dict_values([0.092, 0.776, 0.132, 0.9773]), dict_values([0.074, 0.811, 0.115, 0.9113]), dict_values([0.125, 0.69, 0.185, 0.9769]), dict_values([0.12, 0.806, 0.073, -0.9635]), dict_values([0.07, 0.817, 0.113, 0.9436]), dict_values([0.097, 0.785, 0.11
# ...

# %%
len(data_y)
# Out:
# 25000

# %%
len(data_x)
# Out:
# 25000
